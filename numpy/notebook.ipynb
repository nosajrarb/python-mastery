# %%
import numpy as np

# %%
arr = np.arange(5)

# %%
arr
# Out:
# array([0, 1, 2, 3, 4])

# %%
arr.ndim # number of dimensions
# Out:
# 1

# %%
arr.shape # shape
# Out:
# (5,)

# %%
arr.size #total element
# Out:
# 5

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
#every element in a numpy array must be of the same type and size
#if an arrays elements are also arrays, those inner arrays must be of the same type and same number of elements

# %%
stringg = np.array([1, 'hi', 3])

# %%
type(stringg)
# Out:
# numpy.ndarray

# %%
stringg.dtype #numpy casts the integers into the string type
# Out:
# dtype('<U21')
